# %% [markdown]
# # 有理数和无理数

# %% [markdown]
# ## 有理数

# %% [markdown]
# 有理数按照大小可以分为正有理数、0和负有理数

# %%
print("PI是正有理数")
print("0是有理数")
print("-1是负有理数")
# Out:
# PI是正有理数
# 0是有理数
# -1是负有理数

# %%
a = input()
print(a)
# Out:
# 123
# 123

# %% [markdown]
# ![%E4%B8%8B%E8%BD%BD.png](attachment:%E4%B8%8B%E8%BD%BD.png)
